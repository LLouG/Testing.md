# %% [markdown]
# <a href="https://colab.research.google.com/github/LLouG/Testing.md/blob/master/Washing_calc_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
base_int = int(input("What is your current base int? "))
level = int(input("What is your level? "))
extra_mp = int(base_int / 10)
#new_base_int = int(base_int + 5)
#new_level = int(level + 1)
desired_level = int(input("What is the desired level you want to calculate? "))
while base_int <= 260:
  print("Base INT:", + base_int)
  print("Level:", level)
  print("Your extra mp is:", + extra_mp)
  base_int += 5
  level += 1
# Out:
# What is your current base int? 1
# What is your level? 1
# What is the desired level you want to calculate? 1
# Base INT:  11 1
# Level:  1
# Your extra mp is: 0
# Base INT:  11 6
# Level:  2
# Your extra mp is: 0
# Base INT:  11 11
# Level:  3
# Your extra mp is: 0
# Base INT:  11 16
# Level:  4
# Your extra mp is: 0
# Base INT:  11 21
# Level:  5
# Your extra mp is: 0
# Base INT:  11 26
# Level:  6
# Your extra mp is: 0
# Base INT:  11 31
# Level:  7
# Your extra mp is: 0
# Base INT:  11 36
# Level:  8
# Your extra mp is: 0
# Base INT:  11 41
# Level:  9
# Your extra mp is: 0
# Base INT:  11 46
# Level:  10
# Your extra mp is: 0
# Base INT:  11 51
# Level:  11
# Your extra mp is: 0
# Base INT:  11 56
# Level:  12
# Your extra mp is: 0
# Base INT:  11 61
# Level:  13
# Your extra mp is: 0
# Base INT:  11 66
# Level:  14
# Your extra mp is: 0
# Base INT:  11 71
# Level:  15
# Your extra mp is: 0
# Base INT:  11 76
# Level:  16
# Your extra mp is: 0
# Base INT:  11 81
# Level:  17
# ...
